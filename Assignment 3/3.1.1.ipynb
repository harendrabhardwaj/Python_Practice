# %%
'''Write a function to compute 5/0 and use try/except to catch the exceptions.'''
# Out:
# 'Write a function to compute 5/0 and use try/except to catch the exceptions.'

# %%
def func1():
  c = 5/0
  return c

# %%
try:
  func1()
except:
  print("Error: Finally get an exception, Now your turn to Handle it......")
# Out:
# Error: Finally get an exception, Now your turn to Handle it......
